# %% [markdown]
# <center><h1><font color='red'>VEILLE TECHNOLOGIQUE SUR LE MODULE PYPLOT DE PYTHON </font><h1><center>

# %% [markdown]
# ![matplotlib-sphx_glr_usage_thumb.jpg](attachment:matplotlib-sphx_glr_usage_thumb.jpg)

# %% [markdown]
# - ## <font color='red'>C'est quoi pyplot?</font>
# - ## <font color='red'>Comment l'installer?</font>
# - ## <font color='red'>Comment s'utilise-t-il?</font>

# %% [markdown]
# ## I. QU'EST-CE QUE PYPLOT?

# %% [raw]
# Pyplot est un module Matplotlib proposant plusieurs fonctions pour tracer des graphes.
#
# Il s'adapte à tous les systèmes d'exploitation tels que MAC, Windows, Linux, Unbutu
#
# Il possède plusieurs fonction dont les plus utilisées sont pplot, scatter, zplot, anotate, tex
#
# Il est très utilisé car son interface est confortable

# %% [markdown]
# ## II. INSTALLATION

# %% [markdown]
# ### 1) Sous WINDOWS

# %% [raw]
# py -m pip install --user -U --upgrade pip
# py -m pip install --user -U matplotlib

# %% [markdown]
# ### 2) Sous LINUX

# %% [raw]
# python3 -m pip install --user -U --upgrade pip
# python3 -m pip install --user -U matplotlib

# %% [raw]
# Ces commandes installent le package matplotlib duquel provient pyplot

# %% [markdown]
# # III. UTILISATION

# %%
# Il faut d'abord l'importer avec la commande 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Il permet de tracer des graphes des plus simples aux plus complexes
# ### Débuter avec une fonction par utilisation de la foction plot qui permet de tracer une distribution en fonction d'une autre
# $$ f(x) = \dfrac{1}{1+e^-x}$$

# %%
import numpy as np  # Pour pouvoir fournir un intervalle de tracée d de notre courbe

# %%
x = np.arange(-10,10)
f_x = 1/(1+np.exp(-x))
plt.plot(x,f_x, )   
plt.

# %% [markdown]
# ### Utilisation de la fonction scatter

# %%
x = np.arange(-10,10)      
f_x = 1/(1+np.exp(-x))     # La fonction à représenter
plt.scatter(x,f_x )       # Pour les nuages de points

# %% [markdown]
# ###  Possibilité d'anoter un graphe avec les fonctions anotate ou text

# %%
x = np.arange(-10,10)      
f_x = 1/(1+np.exp(-x))     # La fonction à représenter
plt.scatter(x,f_x )
plt.title('Représentation de y en fonction de x')
plt.title(r"$ f(x) = \dfrac{1}{1+e^-x}$ ")

plt.axis([-10.5,10,0,2])

plt.text(2, 3.5, 'Point de fonctionnement')
plt.annotate('courbe de la fonction logistique', xy=(1.5, 1), 
xytext=(2,1.5), 
arrowprops=dict(facecolor='black', arrowstyle='->'))
# Out:
# Text(2, 1.5, 'courbe de la fonction logistique')

# %%
import math
plt.suptitle('Titre de la figure', size = 'x-large')
plt.subplot(211)
plt.title('1er graphique')
plt.scatter(range(5), [math.sqrt(x) for x in range(5)])

plt.subplot(212)
plt.title('2eme graphique')
plt.hist([math.sqrt(x) for x in range(50)])
plt.text(1, 8, 'histogramme ....', style = 'italic',
            fontweight = 'bold', fontsize = 20, family = 'serif', rotation = 10)
plt.xlabel('valeurs des x')
plt.figtext(0.1, 0.7, 'texte sur toute la figure', rotation = -45,
               fontsize = 30, color = 'orange', alpha = 0.5, fontweight = 'bold')
# Out:
# Text(0.1, 0.7, 'texte sur toute la figure')
